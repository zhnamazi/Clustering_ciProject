# %% [markdown]
# <a href="https://colab.research.google.com/github/zhnamazi/Clustering_ciProject/blob/Zahra/ClusteringProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Phase 1

# %%
import cv2
import os
from google.colab.patches import cv2_imshow

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataset_path = "/content/drive/MyDrive/Colab Notebooks/clustering project/dataset"
# !ls "/content/drive/MyDrive/Colab Notebooks/clustering project/dataset"
# Out:
# Streaming output truncated to the last 5000 lines.
#  002149.jpg	   009267.jpg	     016415.jpg   023563.jpg   030711.jpg   037859.jpg	 045007.jpg
#  002150.jpg	   009268.jpg	     016416.jpg   023564.jpg   030712.jpg   037860.jpg	 045008.jpg
#  002151.jpg	   009269.jpg	     016417.jpg   023565.jpg   030713.jpg   037861.jpg	 045009.jpg
#  002152.jpg	   009270.jpg	     016418.jpg   023566.jpg   030714.jpg   037862.jpg	 045010.jpg
#  002153.jpg	   009271.jpg	     016419.jpg   023567.jpg   030715.jpg   037863.jpg	 045011.jpg
#  002154.jpg	   009272.jpg	     016420.jpg   023568.jpg   030716.jpg   037864.jpg	 045012.jpg
#  002155.jpg	   009273.jpg	     016421.jpg   023569.jpg   030717.jpg   037865.jpg	 045013.jpg
#  002156.jpg	   009274.jpg	     016422.jpg   023570.jpg   030718.jpg   037866.jpg	 045014.jpg
#  002157.jpg	   009275.jpg	     016423.jpg   023571.jpg   030719.jpg   037867.jpg	 045015.jpg
# ...

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
img = cv2.imread(os.path.join(dataset_path, '050000.jpg'))
# cv2_imshow(img)
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# cv2_imshow(gray_img)
print(img.shape)
# Out:
# (218, 178, 3)

# %%
face = face_cascade.detectMultiScale(
    gray_img, scaleFactor=1.1, minNeighbors=5, minSize=(50, 50)
)
print(face)
# Out:
# [[ 39  74 101 101]]

# %%
for (x, y, w, h) in face:
    cv2.rectangle(img, (x, y), (x+w, y+h), (0, 0, 255), 2)

# Display the image with detected faces
cv2_imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=178x218>
